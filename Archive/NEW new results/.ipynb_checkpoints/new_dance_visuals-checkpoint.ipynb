# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#cosine similarity
expert = {'therapy':0.17397138,
'kathak':0.48855776,
'exercise':0.13069183,
'bellydance':0.48701745,
'dabke':0.4927434,
'choreo':0.3851452,
'song':0.43922,
'rhythm':0.44488007,
'breakdance':0.5656346,
'singing':0.56913227,
'drumming':0.46487707,
'chorus':0.4689573,
'round':0.034674823,
'natyam':0.48214597,
'salsa':0.5699522,
'pop':0.4782698,
'tap':0.3553719,
'folkdance':0.49112776,
'beatboxing':0.4530424,
'sneakers':0.27297443,
'count':-0.025559317,
'sweat':0.27964684,
'lavani':0.47219124,
'ballet':0.5622532,
'choreographer':0.46992043}

# %%
#cosine similarity
novice = {'therapy':0.16058493,
'ballet':0.54813695,
'natyam':0.4576169,
'drumming':0.46271932,
'bellydance':0.44882172,
'choreo':0.3001919,
'folkdance':0.4368557,
'choreographer':0.47276494,
'pop':0.49145207,
'rhythm':0.44791624,
'count':-0.013142229,
'singing':0.56947213,
'beatboxing':0.46457443,
'sweat':0.26551065,
'exercise':0.13884877,
'chorus':0.4665798,
'tap':0.36737522,
'kathak':0.4537797,
'sneakers':0.2754433,
'song':0.43945962,
'salsa':0.5521809,
'round':0.028768847,
'lavani':0.43384257,
'dabke':0.41238636,
'breakdance':0.53486884}

# %%
df = pd.Series(expert).to_frame()
df.columns = ['expert']
df1 = pd.Series(novice).to_frame()
df1.columns = ['novice']

# %%
new = df.join(df1)

# %%
new
# Out:
#                  expert    novice
# therapy        0.173971  0.160585
# kathak         0.488558  0.453780
# exercise       0.130692  0.138849
# bellydance     0.487017  0.448822
# dabke          0.492743  0.412386
# choreo         0.385145  0.300192
# song           0.439220  0.439460
# rhythm         0.444880  0.447916
# breakdance     0.565635  0.534869
# singing        0.569132  0.569472
# drumming       0.464877  0.462719
# chorus         0.468957  0.466580
# round          0.034675  0.028769
# natyam         0.482146  0.457617
# salsa          0.569952  0.552181
# pop            0.478270  0.491452
# tap            0.355372  0.367375
# folkdance      0.491128  0.436856
# beatboxing     0.453042  0.464574
# sneakers       0.272974  0.275443
# count         -0.025559 -0.013142
# sweat          0.279647  0.265511
# lavani         0.472191  0.433843
# ballet         0.562253  0.548137
# choreographer  0.469920  0.472765

# %%
new.plot(y=["expert","novice"], kind="bar", figsize=(15,5))

# %%
expert1={'therapy':[('therapies', 0.7365477085113525), ('psychotherapy', 0.6787686347961426), ('therapists', 0.6572787165641785), ('therapeutic', 0.6523617506027222), ('treatments', 0.634113073348999), ('therapist', 0.6302936673164368), ('pharmacotherapy', 0.6135773658752441), ('treatment', 0.6075640320777893), ('biofeedback', 0.6033389568328857), ('chemotherapy', 0.6010071039199829)]
,'kathak':[('bharatanatyam', 0.8907935619354248), ('odissi', 0.8584927916526794), ('bharatnatyam', 0.8520854115486145), ('kuchipudi', 0.851509153842926), ('mohiniyattam', 0.8062803745269775), ('natyam', 0.7953596115112305), ('bharathanatyam', 0.7942394614219666), ('kathakali', 0.7856155037879944), ('dhrupad', 0.7575832009315491), ('sattriya', 0.7498809099197388)]
,'exercise':[('exercises', 0.6817169189453125), ('exercising', 0.5867849588394165), ('rimpac', 0.5387420654296875), ('comptuex', 0.5229902267456055), ('fleetex', 0.5229861736297607), ('reforger', 0.4983120560646057), ('sharem', 0.4830062985420227), ('exertion', 0.479826420545578), ('balikatan', 0.47174009680747986), ('jtfex', 0.46739068627357483)]
,'bellydance':[('bhangra', 0.5426427125930786), ('worldbeat', 0.5037684440612793), ('chaabi', 0.4980030059814453), ('electroclash', 0.49653512239456177), ('gnawa', 0.4921959340572357), ('dance', 0.487017422914505), ('psychobilly', 0.4827142655849457), ('afrobeat', 0.4808701276779175), ('mbalax', 0.47766727209091187), ('salegy', 0.469157874584198)]
,'dabke':[('khigga', 0.5785078406333923), ('havası', 0.5636061429977417), ('zeybek', 0.5630929470062256), ('attan', 0.5501142740249634), ('dabkeh', 0.5500001907348633), ('karsilamas', 0.5474053025245667), ('mahari', 0.5402480959892273), ('zonaradiko', 0.5399159789085388), ('gotipua', 0.5351734161376953), ('muwashshah', 0.5347257256507874)]
,'choreo':[('dance', 0.3851452171802521), ('cakewalk', 0.37484705448150635), ('azonto', 0.3623088598251343), ('breakdance', 0.35921919345855713), ('fusion', 0.3534318804740906), ('voguing', 0.3455914258956909), ('throwouts', 0.3448787331581116), ('pantsula', 0.34066689014434814), ('unsquare', 0.3393775224685669), ('jitterbug', 0.3377091884613037)]
,'song':[('album', 0.7799625992774963), ('ballad', 0.7379658222198486), ('songs', 0.7349522113800049), ('remix', 0.698671281337738), ('tune', 0.6908552646636963), ('melody', 0.6606062650680542), ('duet', 0.659087598323822), ('lyrics', 0.6576361656188965), ('soundtrack', 0.6538525223731995), ('rendition', 0.636414647102356)]
,'rhythm':[('rhythms', 0.6595417261123657), ('syncopated', 0.6486065983772278), ('syncopation', 0.6244393587112427), ('melody', 0.6221169829368591), ('bassline', 0.6189500093460083), ('rhythmic', 0.6136929988861084), ('percussive', 0.6113110184669495), ('backbeat', 0.6085230708122253), ('handclaps', 0.5986297130584717), ('melodic', 0.5967814326286316)]
,'breakdance':[('breakdancing', 0.7531691789627075), ('krumping', 0.5788361430168152), ('dance', 0.565634548664093), ('jabbawockeez', 0.5580266714096069), ('krump', 0.5507034063339233), ('hiphop', 0.5355144739151001), ('rap', 0.5049817562103271), ('jitterbug', 0.5004854202270508), ('lambada', 0.4974011182785034), ('jumpstyle', 0.49507036805152893)]
,'singing':[('dancing', 0.6940211653709412), ('sing', 0.6812646389007568), ('crooning', 0.6343996524810791), ('sings', 0.6308874487876892), ('scatting', 0.6287457942962646), ('rapping', 0.6165491342544556), ('sang', 0.6078972816467285), ('serenades', 0.59589684009552), ('singers', 0.5949292182922363), ('yodeling', 0.5902888774871826)]
,'drumming':[('percussion', 0.6664708852767944), ('basslines', 0.6293700337409973), ('noodling', 0.6282740831375122), ('beatboxing', 0.6254535913467407), ('fingerpicking', 0.6222716569900513), ('soloing', 0.6181434392929077), ('percussive', 0.6179395914077759), ('handclaps', 0.6145471334457397), ('solos', 0.6130298376083374), ('guitar', 0.6101610660552979)]
,'chorus':[('choruses', 0.7252562642097473), ('melody', 0.6420540809631348), ('chorale', 0.6161642074584961), ('choir', 0.6048098802566528), ('lyric', 0.6046192049980164), ('outro', 0.5934432744979858), ('intro', 0.5870144367218018), ('verse', 0.5860958099365234), ('singing', 0.581701397895813), ('song', 0.5665144920349121)]
,'round':[('rounds', 0.6594461798667908), ('semifinals', 0.604642391204834), ('semifinal', 0.6017065048217773), ('quarterfinals', 0.6001389026641846), ('semis', 0.5776537656784058), ('finals', 0.5586128234863281), ('quarterfinal', 0.5516539216041565), ('quarter', 0.5478911995887756), ('seeded', 0.5421553254127502), ('tournament', 0.5370155572891235)]
,'natyam':[('kuchipudi', 0.8342295289039612), ('bharatanatyam', 0.8237184286117554), ('kathak', 0.7953596115112305), ('bharathanatyam', 0.7857387661933899), ('odissi', 0.7844802141189575), ('nritya', 0.7795822024345398), ('bharatnatyam', 0.77651047706604), ('mohiniyattam', 0.7745167016983032), ('abhinaya', 0.7591575384140015), ('natya', 0.7450645565986633)]
,'salsa':[('merengue', 0.7961260080337524), ('cumbia', 0.7531505823135376), ('bachata', 0.7366011142730713), ('rumba', 0.7259712219238281), ('reggaeton', 0.7058507800102234), ('danzón', 0.684455156326294), ('charanga', 0.6840370893478394), ('ranchera', 0.6837963461875916), ('norteña', 0.6816244125366211), ('mariachi', 0.6802345514297485)]
,'pop':[('electropop', 0.6525511741638184), ('disco', 0.6494101285934448), ('europop', 0.6332992315292358), ('reggae', 0.6332694292068481), ('rap', 0.6200146675109863), ('eurodance', 0.6173620223999023), ('electroclash', 0.6014662981033325), ('rockabilly', 0.6004797220230103), ('punk', 0.5928802490234375), ('electronica', 0.5850915908813477)]
,'tap':[('taps', 0.5777058601379395), ('tapping', 0.5355331301689148), ('spın̈al', 0.47544488310813904), ('coax', 0.4366021156311035), ('pull', 0.4286821484565735), ('switch', 0.4175439476966858), ('bump', 0.41619813442230225), ('spile', 0.4154539406299591), ('squeeze', 0.4098949730396271), ('stomp', 0.4083024859428406)]
,'folkdance':[('kalamatianos', 0.5148463249206543), ('syrtos', 0.5026224851608276), ('contredanse', 0.5004878640174866), ('dance', 0.49112772941589355), ('sirtaki', 0.4898478388786316), ('dances', 0.4852256178855896), ('zeibekiko', 0.4742785394191742), ('χορός', 0.46424996852874756), ('csárdás', 0.4605238735675812), ('tanec', 0.4591527283191681)]
,'beatboxing':[('beatbox', 0.6904387474060059), ('drumming', 0.6254535913467407), ('rapping', 0.6249586343765259), ('turntablism', 0.619375467300415), ('freestyling', 0.6090054512023926), ('scatting', 0.6061279773712158), ('breakdancing', 0.5956095457077026), ('breakbeats', 0.5845046043395996), ('beatboxer', 0.5768030881881714), ('handclaps', 0.5711221694946289)]
,'sneakers':[('shoes', 0.7181237936019897), ('tracksuits', 0.6698959469795227), ('jeans', 0.6604092121124268), ('hoodies', 0.6485450267791748), ('tights', 0.6408107280731201), ('boots', 0.6404956579208374), ('pants', 0.6329089999198914), ('sunglasses', 0.6289175152778625), ('panties', 0.6257046461105347), ('sneaker', 0.62333083152771)]
,'count':[('counts', 0.649979293346405), ('giselbert', 0.5387555360794067), ('looz', 0.537278950214386), ('laurenburg', 0.5350704789161682), ('margrave', 0.5343506932258606), ('chiny', 0.53404700756073), ('toerring', 0.5061140060424805), ('astarac', 0.5023221373558044), ('egisheim', 0.5021179914474487), ('wifred', 0.49676722288131714)]
,'sweat':[('perspiration', 0.5664153695106506), ('pocari', 0.5378638505935669), ('oozing', 0.5318280458450317), ('sweating', 0.5135902762413025), ('saliva', 0.5118255615234375), ('spurting', 0.5063459873199463), ('splattering', 0.48282405734062195), ('curdling', 0.48044830560684204), ('dripping', 0.4791952967643738), ('blood', 0.4785439968109131)]
,'lavani':[('thumri', 0.734810471534729), ('tamasha', 0.7264381647109985), ('bhajans', 0.7227315902709961), ('ghoomar', 0.7168765068054199), ('khyal', 0.7111274600028992), ('bhajan', 0.7104078531265259), ('khayal', 0.7062883377075195), ('tappa', 0.7043511867523193), ('yakshagana', 0.6994137167930603), ('kirtan', 0.6925714015960693)]
,'ballet':[('opera', 0.6597005724906921), ('ballets', 0.6502339243888855), ('ballerina', 0.6250637769699097), ('choreographic', 0.6216468811035156), ('choreographer', 0.6181526184082031), ('balanchine', 0.6091122031211853), ('massine', 0.6047346591949463), ('nijinska', 0.6003656387329102), ('nycb', 0.59162437915802), ('theatre', 0.5887306928634644)]
,'choreographer':[('dancer', 0.6816524267196655), ('choreographers', 0.6711935997009277), ('choreographed', 0.6529881358146667), ('choreography', 0.6344748735427856), ('ballet', 0.6181526184082031), ('cinematographer', 0.5827420353889465), ('composer', 0.5719830989837646), ('actor', 0.5689380168914795), ('choreographing', 0.5686152577400208), ('actress', 0.5585271120071411)]}

# %%
novice1={'therapy':[('therapies', 0.7262734770774841), ('psychotherapy', 0.6551139950752258), ('therapists', 0.6491149663925171), ('therapist', 0.63447105884552), ('treatments', 0.6307684183120728), ('therapeutic', 0.620594322681427), ('treatment', 0.6114627718925476), ('chemotherapy', 0.6108567714691162), ('pharmacotherapy', 0.5949303507804871), ('phototherapy', 0.5862945318222046)]
,'ballet':[('ballets', 0.6590582132339478), ('opera', 0.6580528616905212), ('choreographer', 0.6245375275611877), ('choreographic', 0.6179386377334595), ('ballerina', 0.6000000238418579), ('theatre', 0.5950865745544434), ('balanchine', 0.5913684368133545), ('nycb', 0.5900249481201172), ('coppélia', 0.5885660648345947), ('massine', 0.5869631767272949)]
,'natyam':[('bharatanatyam', 0.8164868354797363), ('kuchipudi', 0.8116306066513062), ('bharathanatyam', 0.7947945594787598), ('kathak', 0.7932531833648682), ('odissi', 0.7881475687026978), ('bharatnatyam', 0.7767365574836731), ('abhinaya', 0.7620129585266113), ('mohiniyattam', 0.756506085395813), ('nritya', 0.7550767064094543), ('kathakali', 0.7424626350402832)]
,'drumming':[('percussion', 0.674792468547821), ('fingerpicking', 0.6340452432632446), ('basslines', 0.6270840764045715), ('drumset', 0.6232144832611084), ('soloing', 0.6204729080200195), ('congas', 0.6174321174621582), ('beatboxing', 0.6150908470153809), ('guitar', 0.6097519397735596), ('polyrhythms', 0.6096745133399963), ('scatting', 0.6082789897918701)]
,'bellydance':[('bhangra', 0.5038999915122986), ('worldbeat', 0.4968765377998352), ('electroclash', 0.48157787322998047), ('burlesque', 0.4550989866256714), ('bellydancers', 0.45182308554649353), ('marabi', 0.4497358798980713), ('dance', 0.4488217234611511), ('chaabi', 0.440605103969574), ('mbaqanga', 0.4403461515903473), ('taarab', 0.4398156702518463)]
,'choreo':[('cougarettes', 0.3775830864906311), ('worldbeat', 0.3413642644882202), ('afrobeat', 0.33652564883232117), ('breakdance', 0.32591450214385986), ('cakewalk', 0.32586610317230225), ('jitterbug', 0.3235664367675781), ('bhangra', 0.32105302810668945), ('octamed', 0.3197394609451294), ('cheerleading', 0.31940770149230957), ('freedance', 0.319018691778183)]
,'folkdance':[('folkloric', 0.4758060574531555), ('contredanse', 0.4711213707923889), ('dances', 0.4710148870944977), ('matachines', 0.44366347789764404), ('hojagiri', 0.4423998296260834), ('linđo', 0.43980881571769714), ('dance', 0.436855673789978), ('peridance', 0.4305448532104492), ('comparsas', 0.42150700092315674), ('folklórico', 0.41905051469802856)]
,'choreographer':[('dancer', 0.6802984476089478), ('choreographers', 0.6674191951751709), ('choreographed', 0.6520140171051025), ('choreography', 0.6441406607627869), ('ballet', 0.6245375275611877), ('cinematographer', 0.5805082321166992), ('composer', 0.5705723762512207), ('balletmaster', 0.5680849552154541), ('choreographing', 0.5628970861434937), ('actor', 0.5593191385269165)]
,'pop':[('europop', 0.6791204214096069), ('disco', 0.6552621126174927), ('reggae', 0.6543281078338623), ('electropop', 0.6401231288909912), ('rap', 0.635354220867157), ('rockabilly', 0.6128711104393005), ('electroclash', 0.5981581211090088), ('eurodance', 0.5975080728530884), ('downtempo', 0.5972356200218201), ('electronica', 0.5885456800460815)]
,'rhythm':[('rhythms', 0.6785223484039307), ('backbeat', 0.6379595994949341), ('syncopated', 0.6352115869522095), ('syncopation', 0.6299446225166321), ('polyrhythmic', 0.6174154281616211), ('handclaps', 0.6093094944953918), ('staccato', 0.6085988879203796), ('melodic', 0.6067739129066467), ('basslines', 0.6066586971282959), ('bassline', 0.6054595112800598)]
,'count':[('counts', 0.6533509492874146), ('giselbert', 0.5544921159744263), ('margrave', 0.5389668941497803), ('laurenburg', 0.5142308473587036), ('hasimir', 0.5134862661361694), ('lamoral', 0.5133675336837769), ('wiprecht', 0.513265073299408), ('pfannberg', 0.5130853652954102), ('looz', 0.5125002264976501), ('chiny', 0.5080490112304688)]
,'singing':[('dancing', 0.7006425857543945), ('sing', 0.6763883233070374), ('crooning', 0.6300510168075562), ('sings', 0.61865234375), ('rapping', 0.609039843082428), ('sang', 0.6075634360313416), ('scatting', 0.6000996828079224), ('singers', 0.596916913986206), ('performing', 0.5967919826507568), ('yodeling', 0.5940030813217163)]
,'beatboxing':[('beatbox', 0.663329005241394), ('turntablism', 0.6434850692749023), ('rapping', 0.6343994140625), ('drumming', 0.6150908470153809), ('scatting', 0.6150450706481934), ('mcing', 0.5992493629455566), ('freestyling', 0.5955688953399658), ('beatboxer', 0.5874425768852234), ('breakdancing', 0.5820156335830688), ('rahzel', 0.5795223116874695)]
,'sweat':[('pocari', 0.5765771865844727), ('perspiration', 0.5700954794883728), ('oozing', 0.5321716666221619), ('splattering', 0.5260846614837646), ('breakn', 0.5214592218399048), ('sweating', 0.5175590515136719), ('spurting', 0.5166917443275452), ('saliva', 0.5151323080062866), ('dripping', 0.4918380379676819), ('phlegm', 0.4906935393810272)]
,'exercise':[('exercises', 0.6754328012466431), ('exercising', 0.5790612101554871), ('rimpac', 0.5514653325080872), ('fleetex', 0.5039156079292297), ('sharem', 0.48305314779281616), ('reforger', 0.48232102394104004), ('calisthenic', 0.4809824824333191), ('balikatan', 0.4782242774963379), ('comptuex', 0.47796520590782166), ('tropex', 0.4711969494819641)]
,'chorus':[('choruses', 0.7221107482910156), ('melody', 0.6539022326469421), ('chorale', 0.624285101890564), ('choir', 0.6008314490318298), ('outro', 0.5987071990966797), ('intro', 0.5910724401473999), ('lyric', 0.588241457939148), ('verse', 0.5813846588134766), ('coda', 0.5746137499809265), ('song', 0.5688091516494751)]
,'tap':[('taps', 0.5883795022964478), ('tapping', 0.5351515412330627), ('spın̈al', 0.48016589879989624), ('pull', 0.44101661443710327), ('coax', 0.4309384524822235), ('squirted', 0.420940101146698), ('bump', 0.42064201831817627), ('slide', 0.4184306859970093), ('insert', 0.4177853465080261), ('squeeze', 0.4135960340499878)]
,'kathak':[('bharatanatyam', 0.9007102251052856), ('odissi', 0.868131160736084), ('bharatnatyam', 0.8672073483467102), ('kuchipudi', 0.860174298286438), ('bharathanatyam', 0.801482081413269), ('natyam', 0.7932531833648682), ('mohiniyattam', 0.7798326015472412), ('kathakali', 0.7661659717559814), ('nritya', 0.7348721623420715), ('sattriya', 0.7339436411857605)]
,'sneakers':[('shoes', 0.7264565825462341), ('tracksuits', 0.6754555702209473), ('jeans', 0.660959005355835), ('boots', 0.6537033319473267), ('pants', 0.6485449075698853), ('hoodies', 0.6451581716537476), ('sweatpants', 0.6428403258323669), ('sunglasses', 0.638813853263855), ('denim', 0.6357805728912354), ('tracksuit', 0.6352863311767578)]
,'song':[('album', 0.7813790440559387), ('songs', 0.7339333295822144), ('ballad', 0.7292571663856506), ('remix', 0.6962857246398926), ('tune', 0.6855804920196533), ('duet', 0.6552330255508423), ('lyrics', 0.6545431613922119), ('soundtrack', 0.6536704301834106), ('melody', 0.6509004831314087), ('rendition', 0.6326441168785095)]
,'salsa':[('merengue', 0.8046220541000366), ('cumbia', 0.7503141760826111), ('bachata', 0.7391010522842407), ('rumba', 0.7302895188331604), ('reggaeton', 0.6925450563430786), ('danzón', 0.6910628080368042), ('timba', 0.684998631477356), ('charanga', 0.6801643967628479), ('guaracha', 0.6750935316085815), ('bolero', 0.6746408939361572)]
,'round':[('rounds', 0.6599612832069397), ('semifinals', 0.6102886199951172), ('semifinal', 0.6074358224868774), ('quarterfinals', 0.603845477104187), ('semis', 0.5567373633384705), ('finals', 0.5561811923980713), ('quarter', 0.5546053647994995), ('quarterfinal', 0.5527716279029846), ('playoffs', 0.5366005897521973), ('match', 0.534046471118927)]
,'lavani':[('tamasha', 0.7386070489883423), ('thumri', 0.7262893319129944), ('bhajan', 0.7222495675086975), ('ghoomar', 0.7187973260879517), ('geet', 0.7162623405456543), ('bhavai', 0.7157741785049438), ('nautanki', 0.715480625629425), ('tappa', 0.7144145965576172), ('yakshagana', 0.708550751209259), ('jhumur', 0.7084953784942627)]
,'dabke':[('mizmar', 0.5817464590072632), ('dabkeh', 0.5476813912391663), ('chaabi', 0.5445987582206726), ('zajal', 0.5309985280036926), ('ghoomar', 0.5275763869285583), ('karsilamas', 0.525944709777832), ('lavani', 0.5252237319946289), ('havası', 0.5233738422393799), ('jhumur', 0.5209855437278748), ('tarab', 0.5168452262878418)]
,'breakdance':[('breakdancing', 0.7272286415100098), ('krumping', 0.5610141754150391), ('dance', 0.5348687767982483), ('mcing', 0.5249592661857605), ('hiphop', 0.5118414163589478), ('voguing', 0.5063250064849854), ('beatboxing', 0.5019247531890869), ('breakdancers', 0.4932297468185425), ('turntablism', 0.4878535866737366), ('jabbawockeez', 0.4865855872631073)]}

# %%
sim = pd.Series(expert1).to_frame()
sim.columns = ['expert']

# %%
#key:word ; value:list of similar words
e = {}
for k in expert1:
    list1=[v[0] for v in expert1[k]]
    if k in e:
        e[k].append(list1)
    else:
        e[k] = list1

# %%
n = {}
for k in novice1:
    list1=[v[0] for v in novice1[k]]
    if k in n:
        n[k].append(list1)
    else:
        n[k] = list1

# %%
def unique_count(similar_words):
    b = {}
    for key, value in similar_words.items():
        for i in value:            
            if i in b:  
                b[i] += 1  
            else:  
                b[i] = 1 
    return b

# %%
expert_overlappers = unique_count(e)
print(expert_overlappers)
for k,v in expert_overlappers.items():
    if v>1:
        print(k+":"+str(v))
# Out:
# {'therapies': 1, 'psychotherapy': 1, 'therapists': 1, 'therapeutic': 1, 'treatments': 1, 'therapist': 1, 'pharmacotherapy': 1, 'treatment': 1, 'biofeedback': 1, 'chemotherapy': 1, 'bharatanatyam': 2, 'odissi': 2, 'bharatnatyam': 2, 'kuchipudi': 2, 'mohiniyattam': 2, 'natyam': 1, 'bharathanatyam': 2, 'kathakali': 1, 'dhrupad': 1, 'sattriya': 1, 'exercises': 1, 'exercising': 1, 'rimpac': 1, 'comptuex': 1, 'fleetex': 1, 'reforger': 1, 'sharem': 1, 'exertion': 1, 'balikatan': 1, 'jtfex': 1, 'bhangra': 1, 'worldbeat': 1, 'chaabi': 1, 'electroclash': 2, 'gnawa': 1, 'dance': 4, 'psychobilly': 1, 'afrobeat': 1, 'mbalax': 1, 'salegy': 1, 'khigga': 1, 'havası': 1, 'zeybek': 1, 'attan': 1, 'dabkeh': 1, 'karsilamas': 1, 'mahari': 1, 'zonaradiko': 1, 'gotipua': 1, 'muwashshah': 1, 'cakewalk': 1, 'azonto': 1, 'breakdance': 1, 'fusion': 1, 'voguing': 1, 'throwouts': 1, 'pantsula': 1, 'unsquare': 1, 'jitterbug': 2, 'album': 1, 'ballad': 1, 'songs': 1, 'remix': 1, 'tune': 1, 'melody': 3, 'duet': 1, '
# ...

# %%
novice_overlappers = unique_count(n)
print(novice_overlappers)
for k,v in novice_overlappers.items():
    if v>1:
        print(k+":"+str(v))
# Out:
# {'therapies': 1, 'psychotherapy': 1, 'therapists': 1, 'therapist': 1, 'treatments': 1, 'therapeutic': 1, 'treatment': 1, 'chemotherapy': 1, 'pharmacotherapy': 1, 'phototherapy': 1, 'ballets': 1, 'opera': 1, 'choreographer': 1, 'choreographic': 1, 'ballerina': 1, 'theatre': 1, 'balanchine': 1, 'nycb': 1, 'coppélia': 1, 'massine': 1, 'bharatanatyam': 2, 'kuchipudi': 2, 'bharathanatyam': 2, 'kathak': 1, 'odissi': 2, 'bharatnatyam': 2, 'abhinaya': 1, 'mohiniyattam': 2, 'nritya': 2, 'kathakali': 2, 'percussion': 1, 'fingerpicking': 1, 'basslines': 2, 'drumset': 1, 'soloing': 1, 'congas': 1, 'beatboxing': 2, 'guitar': 1, 'polyrhythms': 1, 'scatting': 3, 'bhangra': 2, 'worldbeat': 2, 'electroclash': 2, 'burlesque': 1, 'bellydancers': 1, 'marabi': 1, 'dance': 3, 'chaabi': 2, 'mbaqanga': 1, 'taarab': 1, 'cougarettes': 1, 'afrobeat': 1, 'breakdance': 1, 'cakewalk': 1, 'jitterbug': 1, 'octamed': 1, 'cheerleading': 1, 'freedance': 1, 'folkloric': 1, 'contredanse': 1, 'dances': 1, 'matachines': 1
# ...
