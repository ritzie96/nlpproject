# %%
import numpy as np
import pandas as pd

# %%
f1 = [('tennis', 0.6897783875465393), ('squash', 0.6625572443008423), ('handball', 0.6317065954208374), ('volleyball', 0.6277102828025818), ('netball', 0.5822980403900146), ('futsal', 0.5452399849891663), ('racquetball', 0.48508721590042114), ('gymnastics', 0.472924143075943), ('kabaddi', 0.4712340533733368), ('taekwondo', 0.46664440631866455), ('sport', 0.46345365047454834), ('archery', 0.4624342918395996), ('takraw', 0.4620468020439148), ('basketball', 0.4580974280834198), ('chess', 0.457233726978302), ('korfball', 0.45613786578178406), ('snooker', 0.455863356590271), ('floorball', 0.455460786819458), ('cricket', 0.4501185417175293), ('pbsi', 0.4462316632270813), ('weightlifting', 0.4454213082790375), ('bandy', 0.44440799951553345), ('petanque', 0.44367051124572754), ('pullela', 0.44117772579193115), ('yonex', 0.44102561473846436), ('goalball', 0.4409745931625366), ('throwball', 0.437974214553833), ('suryanaga', 0.43774133920669556), ('wushu', 0.4375074505805969), ('billiards', 0.4373761713504791), ('pétanque', 0.4344980716705322), ('hockey', 0.43391644954681396), ('sepak', 0.4334896206855774), ('carrom', 0.43235254287719727), ('kabbadi', 0.42915546894073486), ('judo', 0.42834654450416565), ('djarum', 0.42215830087661743), ('taekwando', 0.42109939455986023), ('ittf', 0.4177297055721283), ('tournaments', 0.4161367416381836), ('softball', 0.4136030375957489), ('waterpolo', 0.4132826328277588), ('polo', 0.4131436049938202), ('pickleball', 0.41246116161346436), ('rugby', 0.41087931394577026), ('fistball', 0.4088418483734131), ('racketball', 0.40882474184036255), ('football', 0.4060758948326111), ('croquet', 0.4050396978855133), ('boccia', 0.40359365940093994), ('tennikoit', 0.4015131890773773), ('nehwal', 0.39926865696907043), ('athletics', 0.39913541078567505), ('trampolining', 0.39902830123901367), ('cycling', 0.39835500717163086), ('borned', 0.3978896141052246), ('dancesport', 0.3969331979751587), ('sepaktakraw', 0.39659857749938965), ('sports', 0.3936867415904999), ('tenpin', 0.38529103994369507), ('weighlifting', 0.38495615124702454), ('soccer', 0.3840938210487366), ('sportsclub', 0.3827750086784363), ('sevens', 0.3816443681716919), ('sdat', 0.37660330533981323), ('crossminton', 0.3765190839767456), ('bwf', 0.37475550174713135), ('lacrosse', 0.3727843165397644), ('gymnast', 0.3726561665534973), ('raquets', 0.371747225522995), ('clearone', 0.3709118962287903), ('athlete', 0.3704525828361511), ('shuffleboard', 0.3696523904800415), ('draughts', 0.3693045377731323), ('paralympian', 0.3690207004547119), ('armwrestling', 0.3686378598213196), ('racquets', 0.36804404854774475), ('swimming', 0.3661451041698456), ('paralympic', 0.3661050498485565), ('footbag', 0.3646315932273865), ('orienteering', 0.36452919244766235), ('paddleball', 0.36256664991378784), ('kho', 0.36214500665664673), ('mahjong', 0.36202865839004517), ('equestrian', 0.36108916997909546), ('indoor', 0.36006850004196167), ('renju', 0.3589189648628235), ('pgti', 0.35868963599205017), ('tournament', 0.3582645058631897), ('hockeyclub', 0.35804176330566406), ('competitions', 0.35772621631622314), ('sdar', 0.35767483711242676), ('triathlon', 0.3574746549129486), ('ussra', 0.3564854860305786), ('curling', 0.35638535022735596), ('badmintion', 0.35627877712249756), ('triathlete', 0.3560563921928406), ('darts', 0.3549482822418213), ('powerlifting', 0.35490334033966064), ('championships', 0.3529503345489502), ('skating', 0.35285598039627075), ('powerlifter', 0.35285186767578125), ('shuttler', 0.3517891764640808), ('vejju', 0.3506385087966919), ('backgammon', 0.348760187625885), ('woodball', 0.348760187625885), ('multisports', 0.3485574722290039), ('pallikal', 0.3472265601158142), ('doubles', 0.3468097150325775), ('golf', 0.34479495882987976), ('poker', 0.34349870681762695), ('sportswoman', 0.34285998344421387), ('iwbf', 0.3423324525356293), ('wallyball', 0.34229543805122375), ('sukan', 0.34192851185798645), ('bodybuilding', 0.34108173847198486), ('sphairistike', 0.3408106565475464), ('yulianti', 0.3407418727874756), ('swimmer', 0.3406664729118347), ('racewalking', 0.33998703956604004), ('gymkhana', 0.33904018998146057), ('raquetball', 0.3382452130317688), ('amateur', 0.3381132483482361), ('rogaining', 0.3375858962535858), ('bocce', 0.3370159864425659), ('malaysia', 0.3370116353034973), ('battledore', 0.3353005647659302), ('rowing', 0.3348712921142578), ('khokho', 0.33448541164398193), ('multisport', 0.33413368463516235), ('professional', 0.33366167545318604), ('decathlete', 0.33356693387031555), ('percasi', 0.33332231640815735), ('karate', 0.3332320749759674), ('gopichand', 0.3326571583747864), ('ngaimin', 0.3325580656528473), ('footvolley', 0.332545667886734), ('muaythai', 0.3315123915672302), ('oozeball', 0.3310301899909973), ('windsurfer', 0.3306623101234436), ('handballer', 0.3306596875190735), ('racketlon', 0.3306388258934021), ('olympic', 0.33031973242759705), ('xiangqi', 0.3302392065525055), ('rosmalen', 0.3299062252044678), ('jakabaring', 0.32916751503944397), ('panipak', 0.3286912441253662), ('boxing', 0.3286669850349426), ('senayan', 0.3285517692565918), ('cup', 0.32837221026420593), ('biathle', 0.32760506868362427), ('junior', 0.32747042179107666), ('frontenis', 0.32738760113716125), ('wovd', 0.3271633982658386), ('jianzi', 0.3269149661064148), ('kabbaddi', 0.32679283618927), ('tecnifibre', 0.32671070098876953), ('idbf', 0.32486090064048767), ('kurash', 0.3248021602630615), ('athletes', 0.3247474431991577), ('canoeing', 0.32471030950546265), ('tournamentsoftware', 0.3240078091621399), ('embong', 0.32395902276039124), ('windsurfing', 0.323452353477478), ('racewalker', 0.3234344720840454), ('competition', 0.3225109577178955), ('badmintonklub', 0.32243162393569946), ('heptathlete', 0.32241278886795044), ('footbal', 0.32219457626342773), ('cuju', 0.32198023796081543), ('bobsledding', 0.3218722939491272), ('itsf', 0.3217618763446808), ('itf', 0.3217216432094574), ('azizulhasni', 0.32165253162384033), ('alai', 0.3208179175853729), ('quoits', 0.3206251859664917), ('aquathlon', 0.32042786478996277), ('sanshou', 0.3203184902667999), ('biathlon', 0.31941288709640503), ('sprinter', 0.3191309869289398), ('pdga', 0.3190303146839142), ('quizzing', 0.3184441328048706), ('singapore', 0.3182966709136963), ('baseball', 0.31827306747436523), ('federation', 0.31795814633369446), ('intercrosse', 0.31772780418395996), ('wta', 0.31730759143829346), ('lillerød', 0.31728512048721313), ('wbpf', 0.3171555995941162), ('handcycling', 0.3170618712902069), ('recurve', 0.3169591426849365), ('lta', 0.3169209361076355), ('regu', 0.3164169192314148), ('popki', 0.3162384629249573), ('ponsana', 0.3154924511909485), ('interschool', 0.3143288493156433), ('trapshooting', 0.3137805461883545), ('theinbyu', 0.3137050271034241), ('seluruh', 0.3136366605758667), ('setar', 0.3123783469200134)]
f2 = [('dancing', 0.740477442741394), ('dances', 0.7038745880126953), ('dancers', 0.632834255695343), ('music', 0.6078445911407471), ('choreography', 0.5832473635673523), ('danced', 0.5783137083053589), ('sirtaki', 0.5670879483222961), ('singing', 0.5664202570915222), ('disco', 0.5634735226631165), ('salsa', 0.5611661672592163), ('ballet', 0.5606725215911865), ('tango', 0.5591773986816406), ('jitterbug', 0.5571836233139038), ('musical', 0.5524371862411499), ('legong', 0.549941897392273), ('rhumba', 0.5494099259376526), ('voguing', 0.5474625825881958), ('breakdance', 0.5460233092308044), ('breakdancing', 0.5436580181121826), ('unsquare', 0.5386400818824768), ('orchesis', 0.5376227498054504), ('krump', 0.5345757007598877), ('butoh', 0.5276824235916138), ('kecak', 0.5272321701049805), ('bhangra', 0.5268635749816895), ('dancer', 0.5247450470924377), ('flamenco', 0.5245239734649658), ('choreographies', 0.5232276320457458), ('jazz', 0.5230883359909058), ('pilobolus', 0.5177608132362366), ('krumping', 0.5176735520362854), ('lambada', 0.515397310256958), ('cabaret', 0.5116437673568726), ('tinikling', 0.5108423233032227), ('bikutsi', 0.5096401572227478), ('azonto', 0.5094369053840637), ('pangalay', 0.5092140436172485), ('choreographs', 0.5076417326927185), ('quadrille', 0.5074433088302612), ('rumba', 0.5073113441467285), ('cueca', 0.5067597031593323), ('choreographed', 0.5054936408996582), ('ghoomar', 0.5036608576774597), ('tandava', 0.5010902285575867), ('bugaku', 0.5001280307769775), ('pasodoble', 0.49934452772140503), ('striptease', 0.4991567134857178), ('karaoke', 0.49901288747787476), ('choreographic', 0.4975624084472656), ('tarantella', 0.49587661027908325), ('aerobics', 0.4957091808319092), ('balletic', 0.49570512771606445), ('crazes', 0.49469780921936035), ('bagurumba', 0.49288812279701233), ('europop', 0.4921235144138336), ('folklorico', 0.492077499628067), ('burlesque', 0.49140816926956177), ('zapateado', 0.4912850558757782), ('pop', 0.4907382130622864), ('jaipongan', 0.4898701608181), ('giddha', 0.4884793758392334), ('candoco', 0.4884684979915619), ('xibelani', 0.48709607124328613), ('ballroom', 0.4869246184825897), ('milonga', 0.4868144392967224), ('bedhaya', 0.48530063033103943), ('choreographing', 0.4820505976676941), ('samba', 0.4815547466278076), ('cakewalk', 0.48114830255508423), ('chhau', 0.4810526967048645), ('lasya', 0.4800461232662201), ('quickstep', 0.479641854763031), ('dancehall', 0.47918951511383057), ('pantsula', 0.47838667035102844), ('bélé', 0.4778323769569397), ('chinelos', 0.4777911305427551), ('sattriya', 0.47756701707839966), ('kathak', 0.47738373279571533), ('batusi', 0.47643548250198364), ('marinera', 0.47462236881256104), ('cancan', 0.4745430052280426), ('lavani', 0.4742284417152405), ('festejo', 0.4739878177642822), ('denishawn', 0.47394344210624695), ('twerking', 0.4738827347755432), ('cumbia', 0.4738008975982666), ('bharathanatyam', 0.47379493713378906), ('choreograph', 0.4737495481967926), ('mambo', 0.47309160232543945), ('acrobatics', 0.4730577766895294), ('tandav', 0.4727054238319397), ('folkdance', 0.47240325808525085), ('contredanse', 0.4721543788909912), ('chorus', 0.47153395414352417), ('bharatanatyam', 0.47083377838134766), ('sing', 0.4700990915298462), ('sardana', 0.46824443340301514), ('chholiya', 0.46783074736595154), ('waltz', 0.4677180051803589), ('candombe', 0.46746233105659485), ('drumming', 0.4673495292663574), ('improvisation', 0.4664382040500641), ('choreographer', 0.46568170189857483), ('gotipua', 0.4654977023601532), ('estampie', 0.46495872735977173), ('petrunino', 0.46426358819007874), ('danse', 0.4641267657279968), ('zeybek', 0.46376773715019226), ('performers', 0.46306484937667847), ('frevo', 0.46224701404571533), ('agbadza', 0.46200698614120483), ('floorwork', 0.46200594305992126), ('jumbie', 0.4612652063369751), ('sket', 0.4612022638320923), ('reggae', 0.4604952335357666), ('kalamatianos', 0.46010273694992065), ('kolatam', 0.4592299461364746), ('hooping', 0.4585238993167877), ('natyam', 0.4583294093608856), ('merengue', 0.45817551016807556), ('jumpstyle', 0.4579508304595947), ('kizomba', 0.45718708634376526), ('dance”', 0.4571850895881653), ('danza', 0.4570271372795105), ('zouk', 0.45680859684944153), ('mujra', 0.45656701922416687), ('hula', 0.456378310918808), ('veeragase', 0.4563547968864441), ('“dance', 0.45608678460121155), ('hoedown', 0.4555840492248535), ('yakshagana', 0.4552021324634552), ('orissi', 0.45491892099380493), ('zeibekiko', 0.4548230767250061), ('folk', 0.45366501808166504), ('dollu', 0.4534912705421448), ('kamsale', 0.453104704618454), ('improvisational', 0.4525943100452423), ('jwé', 0.45224863290786743), ('pilates', 0.45217210054397583), ('dabke', 0.45186448097229004), ('kuchipudi', 0.45183002948760986), ('parapara', 0.45148026943206787), ('rave', 0.4512380063533783), ('improv', 0.4506661891937256), ('rap', 0.45054858922958374), ('odissi', 0.4501774311065674), ('performing', 0.4501402974128723), ('bharatnatyam', 0.4493710696697235), ('bolero', 0.4485238492488861), ('kuduro', 0.4483407437801361), ('fatele', 0.4477592706680298), ('rhythm', 0.4475046396255493), ('farandole', 0.4471415877342224), ('hiphop', 0.44707176089286804), ('hopak', 0.44684237241744995), ('puppetry', 0.4464353621006012), ('velfarre', 0.4463985562324524), ('tayeh', 0.4462077021598816), ('concert', 0.4460570514202118), ('juggling', 0.4460287392139435), ('dangak', 0.44585394859313965), ('karagattam', 0.44574809074401855), ('carimbó', 0.44521069526672363), ('acrobatic', 0.44512632489204407), ('mime', 0.4443105161190033), ('cachucha', 0.44400548934936523), ('forró', 0.444003701210022), ('maculelê', 0.4437015652656555), ('kroncong', 0.44342079758644104), ('polkas', 0.4432760179042816), ('sokkie', 0.4428674280643463), ('funky', 0.4427716135978699), ('kwassa', 0.4426983594894409), ('jhumar', 0.44238147139549255), ('beatboxing', 0.4421530067920685), ('waacking', 0.4420763850212097), ('merce', 0.44177353382110596), ('twerk', 0.4414791762828827), ('hootchy', 0.4413926601409912), ('zumba', 0.4413544535636902), ('gambuh', 0.44081753492355347), ('nritta', 0.4404657185077667), ('méringue', 0.4400627613067627), ('dancesport', 0.4399051070213318), ('rhythmic', 0.4398673176765442), ('topeng', 0.4398082196712494), ('hop', 0.43930330872535706), ('shiamak', 0.4392491281032562), ('gagaku', 0.43913739919662476), ('mariachi', 0.43877577781677246), ('bellydance', 0.4384216368198395), ('gamelan', 0.438393771648407), ('schottische', 0.4382321238517761), ('song', 0.43778160214424133), ('downtempo', 0.4372626543045044), ('bourrée', 0.4371613562107086), ('nritya', 0.43668729066848755), ('scatting', 0.43668460845947266), ('joged', 0.4354458451271057), ('lmfao', 0.4347686171531677)]
f3 = [('shooters', 0.604934811592102), ('marksman', 0.46138501167297363), ('swimmer', 0.45928284525871277), ('fencer', 0.45821118354797363), ('platformer', 0.45583581924438477), ('sniper', 0.4551457166671753), ('rpg', 0.4454532265663147), ('skier', 0.43645399808883667), ('athlete', 0.4349988102912903), ('pistol', 0.43315503001213074), ('psikyo', 0.4293038249015808), ('racer', 0.42872095108032227), ('cyclist', 0.41546550393104553), ('danmaku', 0.40958482027053833), ('afanasijs', 0.40704625844955444), ('platforming', 0.40667885541915894), ('rower', 0.40533512830734253), ('snowboarder', 0.40060606598854065), ('jumper', 0.39874953031539917), ('assassin', 0.39692485332489014), ('sprinter', 0.3945579528808594), ('shooting', 0.3919382095336914), ('weightlifter', 0.39074021577835083), ('wrestler', 0.38963091373443604), ('thrower', 0.3888590335845947), ('bobsledder', 0.3858870565891266), ('climber', 0.38378798961639404), ('diver', 0.3834969401359558), ('crossbow', 0.3833222985267639), ('player', 0.3827584385871887), ('motorcyclist', 0.38237643241882324), ('rpgs', 0.3820056915283203), ('roguelike', 0.38148149847984314), ('stealth', 0.38071855902671814), ('grappler', 0.38052019476890564), ('airgun', 0.37865015864372253), ('benchrest', 0.3784314692020416), ('qix', 0.3784060478210449), ('game', 0.37795960903167725), ('gameplay', 0.3770217001438141), ('khuru', 0.37494558095932007), ('biathlete', 0.3747151792049408), ('judoka', 0.37336254119873047), ('sidescroller', 0.36959701776504517), ('hurdler', 0.36786895990371704), ('zapper', 0.3661436438560486), ('kuzmins', 0.3655116558074951), ('paintball', 0.36503106355667114), ('bazooka', 0.3647403419017792), ('skeet', 0.3644685447216034), ('karateka', 0.36115795373916626), ('scrolling', 0.35908740758895874), ('multidirectional', 0.3578959107398987), ('gunman', 0.3578086197376251), ('adventure', 0.3577798008918762), ('ambidextrous', 0.3574565052986145), ('sidescrolling', 0.357388973236084), ('revolver', 0.35686445236206055), ('wibarm', 0.356086790561676), ('hitman', 0.35544174909591675), ('decathlete', 0.3552090525627136), ('gymnast', 0.35370784997940063), ('handgun', 0.3530786633491516), ('powerlifter', 0.35304659605026245), ('semiautomatic', 0.35277584195137024), ('varmint', 0.3524743616580963), ('milsim', 0.3523727059364319), ('boxer', 0.35204654932022095), ('jetpack', 0.35200071334838867), ('multiplayer', 0.35116302967071533), ('flamethrower', 0.34936845302581787), ('shotgun', 0.3492022156715393), ('frogwares', 0.3487844467163086), ('battletoads', 0.3485878109931946), ('luger', 0.3484744429588318), ('shot', 0.3471059203147888), ('bushmaster', 0.34613409638404846), ('sharpshooter', 0.34603792428970337), ('driver', 0.34582260251045227), ('darkwatch', 0.3452368676662445), ('skydiver', 0.3450167775154114), ('sabreman', 0.343819260597229), ('balkline', 0.3431224226951599), ('archer', 0.342723548412323), ('rifle', 0.3426554203033447), ('tracker', 0.3422701954841614), ('splatoon', 0.3422194719314575), ('rifleman', 0.3409075140953064), ('skater', 0.34045153856277466), ('slingshot', 0.340429425239563), ('stinger', 0.34023192524909973), ('gündegmaa', 0.33955395221710205), ('minigun', 0.33954328298568726), ('copter', 0.338230699300766), ('canoeist', 0.33726078271865845), ('racewalker', 0.33723896741867065), ('tripwire', 0.3368569612503052), ('brawler', 0.3366084694862366), ('puzzle', 0.3363792300224304), ('windsurfer', 0.3363688588142395), ('rider', 0.33579427003860474), ('platformers', 0.33507034182548523), ('powerslide', 0.33340150117874146), ('barreled', 0.33322614431381226), ('zaxxon', 0.33288896083831787), ('weaponlord', 0.33254268765449524), ('miculek', 0.33161139488220215), ('accutrigger', 0.33046266436576843), ('multicart', 0.3303321599960327), ('timesplitters', 0.33021336793899536), ('arcade', 0.3299158811569214), ('metroidvania', 0.32981064915657043), ('novalogic', 0.3294374942779541), ('stalker', 0.3285318613052368), ('carbine', 0.328349769115448), ('policeman', 0.32763972878456116), ('ea', 0.32759061455726624), ('stuntman', 0.32732048630714417), ('kayaker', 0.326743483543396), ('golgo', 0.32629191875457764), ('kickboxer', 0.32627585530281067), ('weapon', 0.3262242078781128), ('isometric', 0.3260534703731537), ('attacker', 0.32564646005630493), ('firearm', 0.32485461235046387), ('rapier', 0.3245028257369995), ('lightgun', 0.3244022727012634), ('avenger', 0.3240049481391907), ('blade', 0.3233541250228882), ('šekarić', 0.322785347700119), ('cartridge', 0.3225468099117279), ('launcher', 0.32251113653182983), ('taito', 0.3222272992134094), ('bullseye', 0.32207363843917847), ('berserker', 0.32187414169311523), ('puzzler', 0.3218679130077362), ('putter', 0.32144391536712646), ('triathlete', 0.3212767243385315), ('tippmann', 0.3212623596191406), ('pentathlete', 0.3211505711078644), ('golfer', 0.3209405839443207), ('centerfire', 0.32080042362213135), ('cricketer', 0.32072266936302185), ('séwé', 0.32004013657569885), ('cyberdillo', 0.3199371099472046), ('fighter', 0.3195769786834717), ('bullpup', 0.3195471167564392), ('melee', 0.31934821605682373), ('mdk', 0.31917470693588257), ('gaijin', 0.3190554082393646), ('gameloft', 0.3190280795097351), ('thriller', 0.3189328908920288), ('batarangs', 0.318644642829895), ('videogame', 0.3185616135597229), ('swordsman', 0.3181837201118469), ('ipsc', 0.31767022609710693), ('splatterhouse', 0.31765446066856384), ('gunslinger', 0.31698429584503174), ('archery', 0.31650829315185547), ('soldier', 0.3163076639175415), ('plinking', 0.3159383535385132), ('centrefire', 0.3158939480781555), ('safecracker', 0.3157990574836731), ('mountaineer', 0.3155067265033722), ('pinball', 0.3154292404651642), ('mmo', 0.315406858921051), ('forend', 0.31534379720687866), ('ristar', 0.31513941287994385), ('crossminton', 0.3150150179862976), ('treyarch', 0.31498682498931885), ('picatinny', 0.31482890248298645), ('artdink', 0.3148001432418823), ('lucasarts', 0.3147263526916504), ('underwurlde', 0.31458234786987305), ('speargun', 0.3145071268081665), ('seeker', 0.3137849271297455), ('banpresto', 0.3130432963371277), ('welrod', 0.3129619359970093), ('mmorpg', 0.31284743547439575), ('codemasters', 0.3124698996543884), ('ballhandler', 0.3123832941055298), ('headshot', 0.31189796328544617), ('autoloading', 0.311235636472702), ('pilotwings', 0.3112017810344696), ('saboteur', 0.3109006881713867), ('boomzap', 0.31005510687828064), ('tranquiliser', 0.3100409507751465), ('duelist', 0.3095983862876892), ('snowboarding', 0.30924171209335327), ('gamer', 0.30902883410453796), ('mech', 0.3087635636329651), ('konami', 0.30876147747039795), ('blaster', 0.3087605834007263), ('orienteer', 0.30868715047836304), ('teyon', 0.30847829580307007), ('gunbird', 0.3083654046058655), ('daneka', 0.3082813024520874), ('amputee', 0.3081281781196594), ('shotguns', 0.3080870509147644), ('javelin', 0.3080286681652069)]
f4 = [('psychotherapeutic', 0.7650939226150513), ('psychoanalysis', 0.7484089136123657), ('psychodynamic', 0.7431614398956299), ('psychoanalytic', 0.728295624256134), ('hypnotherapy', 0.7068870067596436), ('therapy', 0.6886206865310669), ('psychotherapies', 0.6631516218185425), ('psychiatry', 0.6630269289016724), ('psychology', 0.6553324460983276), ('psychopathology', 0.6415141820907593), ('reichian', 0.6392276287078857), ('gestalt', 0.6325379610061646), ('transpersonal', 0.6318178176879883), ('psychodrama', 0.6297131180763245), ('adlerian', 0.6177070736885071), ('ericksonian', 0.6138336062431335), ('counseling', 0.6127153635025024), ('psychosynthesis', 0.6122796535491943), ('psychotherapists', 0.6118183732032776), ('psychologists', 0.6070711612701416), ('cbt', 0.6027354001998901), ('rebt', 0.5972205996513367), ('bobath', 0.5956426858901978), ('jungian', 0.589072585105896), ('psychopharmacology', 0.5882103443145752), ('mindfulness', 0.5856935977935791), ('hypnosis', 0.5853115916252136), ('therapeutic', 0.581881582736969), ('istdp', 0.5811930894851685), ('psychoanalytical', 0.5783926248550415), ('psychotherapist', 0.5766052007675171), ('bibliotherapy', 0.5753219127655029), ('therapies', 0.5743579864501953), ('counselling', 0.5743108987808228), ('psychological', 0.5724592208862305), ('integrative', 0.5710781812667847), ('neuropsychology', 0.5709189772605896), ('biofeedback', 0.5704319477081299), ('therapists', 0.5655226707458496), ('pharmacotherapy', 0.5609112977981567), ('abreaction', 0.5602890253067017), ('therapist', 0.5596716403961182), ('psychosocial', 0.559561014175415), ('neuroscience', 0.5576291084289551), ('countertransference', 0.5574917793273926), ('psychoanalysts', 0.5560930967330933), ('nondirective', 0.5540256500244141), ('clinical', 0.5540110468864441), ('rogerian', 0.5538456439971924), ('emdr', 0.5512048006057739), ('neurology', 0.54998779296875), ('psychiatric', 0.549053430557251), ('daseinsanalysis', 0.5479527711868286), ('reparative', 0.5462186336517334), ('psychoanalyst', 0.5446383953094482), ('behavioral', 0.543017566204071), ('hypnotism', 0.5418678522109985), ('hakomi', 0.5397120714187622), ('manualized', 0.5393602848052979), ('freudian', 0.5388057231903076), ('psychosurgery', 0.5381370186805725), ('homeopathy', 0.5371620059013367), ('logotherapy', 0.5371139645576477), ('psychophysiology', 0.5324248671531677), ('pedagogy', 0.5319780111312866), ('behaviorism', 0.5308783650398254), ('mentalization', 0.5301662683486938), ('humanistic', 0.5293994545936584), ('phenomenology', 0.5292053818702698), ('cognitive', 0.5288101434707642), ('psychoeducational', 0.527129590511322), ('neuropathology', 0.525545597076416), ('meditation', 0.5225822925567627), ('breathwork', 0.518430233001709), ('ect', 0.5183210372924805), ('schizophrenia', 0.5180875062942505), ('psychoeducation', 0.5176495313644409), ('reparenting', 0.5165101885795593), ('sexology', 0.515830397605896), ('psychiatrists', 0.5131754875183105), ('casriel', 0.5105332136154175), ('clinicians', 0.5098006725311279), ('electroconvulsive', 0.5092625617980957), ('cognition', 0.5089616179466248), ('chiropractic', 0.5078744888305664), ('neurofeedback', 0.5076085925102234), ('neurobiology', 0.5054695010185242), ('experiential', 0.5049660205841064), ('sociological', 0.5038706064224243), ('psychodynamics', 0.5015539526939392), ('phenomenological', 0.5014156103134155), ('neuropsychiatry', 0.5009315013885498), ('attunement', 0.5008237361907959), ('assagioli', 0.4997636675834656), ('holistic', 0.4995453953742981), ('sociometry', 0.4955819845199585), ('lifetrack', 0.49490028619766235), ('psychosomatic', 0.4948817193508148), ('metacognition', 0.4939544200897217), ('craniosacral', 0.4936354160308838), ('lacanian', 0.49327951669692993), ('psychoanalytically', 0.493152379989624), ('neuropsychologist', 0.4911961555480957), ('freud', 0.4901074767112732), ('neurophysiology', 0.4897104501724243), ('transference', 0.48874858021736145), ('somatics', 0.48800814151763916), ('psychopharmacological', 0.48762738704681396), ('mbsr', 0.4872042238712311), ('neurobiological', 0.4870326519012451), ('langs', 0.4865080714225769), ('pediatric', 0.48562848567962646), ('megavitamin', 0.48545315861701965), ('gerontology', 0.4853639304637909), ('parenting', 0.4851091802120209), ('janov', 0.48468273878097534), ('interventions', 0.48435091972351074), ('psychedelics', 0.48301878571510315), ('mbct', 0.4828279912471771), ('psychopathological', 0.4802161157131195), ('psychobiology', 0.47987130284309387), ('psychoneuroimmunology', 0.478830486536026), ('psychologist', 0.4786354899406433), ('psychodynamically', 0.47810032963752747), ('anthroposophy', 0.4773484766483307), ('sfbt', 0.4767041802406311), ('cbtraining', 0.47610342502593994), ('practitioners', 0.47554120421409607), ('behavioural', 0.47536778450012207), ('multitheoretical', 0.4751836359500885), ('autosuggestion', 0.47504761815071106), ('behaviorist', 0.47320854663848877), ('pediatrics', 0.47307753562927246), ('acupuncture', 0.47270238399505615), ('treatments', 0.4726463258266449), ('dianetics', 0.4721146523952484), ('psycholytic', 0.4721039831638336), ('osteopathy', 0.4719437062740326), ('psychosis', 0.4718192517757416), ('neuroscientific', 0.4712884724140167), ('interpersonal', 0.4704791307449341), ('neurorehabilitation', 0.4701136350631714), ('ethnomethodology', 0.47001922130584717), ('sandplay', 0.469157338142395), ('hermeneutics', 0.4682266116142273), ('neuroimaging', 0.46695733070373535), ('freud’s', 0.4664534330368042), ('treatment', 0.46641892194747925), ('dialogical', 0.46538621187210083), ('vygotsky', 0.4642157554626465), ('dermatology', 0.4639107882976532), ('spirituality', 0.4635258913040161), ('mental', 0.4632490575313568), ('parapsychology', 0.4630838632583618), ('naturopathy', 0.4628988802433014), ('adolescents', 0.4627850651741028), ('palliative', 0.4626770615577698), ('psychagogy', 0.46120065450668335), ('lacan', 0.4609675705432892), ('neurologists', 0.4608859419822693), ('teacch', 0.4605092704296112), ('geriatrics', 0.46019625663757324), ('neuropsychiatric', 0.45986083149909973), ('ocd', 0.45955413579940796), ('gottman', 0.45954620838165283), ('psychoses', 0.4594995975494385), ('teaching', 0.45916348695755005), ('psychiatrist', 0.45872682332992554), ('psychometrics', 0.4587267339229584), ('methodological', 0.45870599150657654), ('yoga', 0.4582046866416931), ('neuroendocrinology', 0.4581383466720581), ('criminology', 0.45806705951690674), ('neuro', 0.4580627679824829), ('autogenic', 0.457298219203949), ('behaviourism', 0.45717936754226685), ('neuroplasticity', 0.4568689167499542), ('parapsychological', 0.4565199911594391), ('naikan', 0.45646902918815613), ('analytic', 0.45641469955444336), ('iridology', 0.4560098350048065), ('analytical', 0.4559739828109741), ('anthropology', 0.45581328868865967), ('gendlin', 0.45547789335250854), ('psycholinguistics', 0.4554307758808136), ('clinician', 0.45464015007019043), ('desensitization', 0.454444020986557), ('jung’s', 0.4541408121585846), ('shiatsu', 0.4532693028450012), ('biopsychosocial', 0.4521699547767639), ('linguistics', 0.4517044723033905), ('binswanger', 0.45148903131484985), ('hypnotherapists', 0.4511736333370209), ('epistemology', 0.4509598910808563), ('pharmacogenomics', 0.45080500841140747), ('relational', 0.45068439841270447), ('socialization', 0.45057836174964905), ('rehabilitative', 0.4495639503002167), ('neuroanatomy', 0.4490976929664612), ('interdisciplinary', 0.448991060256958)]

# %%
d1=dict(f1)
d2=dict(f2)
d3=dict(f3)
d4=dict(f4)

# %%
def get_count(d , t1, t2):
    c_t1 = 0
    c_t2 = 0
    for k,v in d.items():
        if v > t1:
            c_t1+=1
        if v < t1 and v > t2:
            c_t2+=1
    return c_t1, c_t2

# %%
print("expert")
th1 = 0.4
th2 =0.1
o1, o2 = get_count(d1,th1,th2)
o3, o4 = get_count(d2,th1,th2)
o5, o6 = get_count(d3,th1,th2)
o7, o8 = get_count(d4,th1,th2)
print('badminton: {} {}'.format(o1,o2))
print('dance:{} {}'.format(o3,o4))
print('shooter:{} {}'.format(o5,o6))
print('psychotherapy:{} {}'.format(o7,o8))
# Out:
# expert
# badminton: 51 149
# dance:200 0
# shooter:18 182
# psychotherapy:200 0

# %%
l1 = [('takraw', 0.5872399210929871), ('squash', 0.5862165689468384), ('tennis', 0.5776712894439697), ('throwball', 0.5722858905792236), ('netball', 0.5710862874984741), ('volleyball', 0.5424487590789795), ('kabbadi', 0.5303324460983276), ('carrom', 0.5301637649536133), ('sepak', 0.5289499759674072), ('pickleball', 0.5281351804733276), ('croquet', 0.5252724885940552), ('shuffleboard', 0.5239379405975342), ('bocce', 0.5215163230895996), ('trampolining', 0.5162640810012817), ('racketball', 0.5162001848220825), ('archery', 0.514308750629425), ('pétanque', 0.4939175844192505), ('racquetball', 0.49377092719078064), ('kabaddi', 0.49005332589149475), ('khokho', 0.4799492359161377), ('kabbaddi', 0.4770626425743103), ('intramurals', 0.4762471914291382), ('competitions', 0.4735238254070282), ('waterpolo', 0.47207266092300415), ('dancesport', 0.47052156925201416), ('futsal', 0.4684699475765228), ('billiards', 0.46079152822494507), ('handball', 0.45934388041496277), ('softball', 0.4574812054634094), ('tennikoit', 0.45548301935195923), ('petanque', 0.4529695212841034), ('dodgeball', 0.45209649205207825), ('fistball', 0.44935691356658936), ('tournaments', 0.4437639117240906), ('interschool', 0.4436115622520447), ('swimming', 0.4417668581008911), ('gymkhana', 0.44018664956092834), ('indoor', 0.43974220752716064), ('carom', 0.43694767355918884), ('equestrianism', 0.43624117970466614), ('wallyball', 0.43607234954833984), ('sport', 0.4301876723766327), ('gymnastics', 0.42628172039985657), ('sdat', 0.4260913133621216), ('gyms', 0.424191415309906), ('raquetball', 0.4241716265678406), ('korfball', 0.4233829975128174), ('quoits', 0.4200422763824463), ('goalball', 0.41904065012931824), ('kickball', 0.4189510941505432), ('tenpin', 0.4186525344848633), ('sepaktakraw', 0.4186272621154785), ('intramural', 0.415428102016449), ('foosball', 0.414039671421051), ('floorball', 0.4133949875831604), ('gymnasiums', 0.4102449417114258), ('interhouse', 0.40773114562034607), ('sports', 0.40611693263053894), ('kho', 0.405796080827713), ('weightlifting', 0.40255916118621826), ('zorbing', 0.40190833806991577), ('aerobics', 0.40063416957855225), ('frisbee', 0.39954352378845215), ('boccia', 0.39680996537208557), ('kurash', 0.39647752046585083), ('sitzball', 0.39550960063934326), ('athletics', 0.39503371715545654), ('racquets', 0.39427173137664795), ('clubs', 0.3941115140914917), ('judo', 0.393205463886261), ('wushu', 0.39234864711761475), ('backgammon', 0.39073246717453003), ('cricket', 0.3890019953250885), ('vigoro', 0.38879743218421936), ('boules', 0.38663846254348755), ('pelota', 0.3860321640968323), ('biking', 0.385431170463562), ('horseriding', 0.38434797525405884), ('bandy', 0.38364893198013306), ('canoeing', 0.38308262825012207), ('playgrounds', 0.38289809226989746), ('cornhole', 0.3813517391681671), ('taekwando', 0.37805503606796265), ('finswimming', 0.37748679518699646), ('footbag', 0.3772071599960327), ('gymnastic', 0.37648606300354004), ('skittles', 0.37645405530929565), ('billiard', 0.3751641511917114), ('riflery', 0.3750842809677124), ('yonex', 0.37344473600387573), ('multisport', 0.3724716007709503), ('pullela', 0.37209951877593994), ('cheerleading', 0.3720308542251587), ('extracurriculars', 0.3700945973396301), ('powerlifting', 0.3679799437522888), ('kayaking', 0.3649362325668335), ('dartchery', 0.36434173583984375), ('ergometers', 0.36364904046058655), ('wakeboarding', 0.3630576729774475), ('cycling', 0.36220723390579224), ('shuttlecock', 0.3620057702064514), ('larong', 0.3619357943534851), ('raquets', 0.36033448576927185), ('bachdjarah', 0.3593822121620178), ('gatka', 0.3589782118797302), ('championships', 0.3578917384147644), ('outdoor', 0.35782885551452637), ('minifootball', 0.35777145624160767), ('skiing', 0.35666170716285706), ('frontenis', 0.35665470361709595), ('rounders', 0.3563234806060791), ('taekwondo', 0.35615187883377075), ('ekiring', 0.3560831546783447), ('sukan', 0.3560411334037781), ('ittf', 0.355840802192688), ('polocrosse', 0.3558233678340912), ('malherbie', 0.3543877601623535), ('biathle', 0.3537153899669647), ('orienteering', 0.3533969223499298), ('gym', 0.353074312210083), ('pong', 0.353045791387558), ('playground', 0.3514639139175415), ('taraflex', 0.3509317636489868), ('fistf', 0.3503391146659851), ('mahjong', 0.3498733639717102), ('snooker', 0.3493081331253052), ('nivia', 0.34906870126724243), ('powerboating', 0.3489764332771301), ('tobogganing', 0.3485735058784485), ('equestrian', 0.34850627183914185), ('waterskiing', 0.3478146195411682), ('broomball', 0.34743839502334595), ('realsports', 0.3473101854324341), ('competition', 0.34724754095077515), ('fencing', 0.34691524505615234), ('watersports', 0.34674882888793945), ('paddleball', 0.3465866446495056), ('windsurfing', 0.3464049696922302), ('basketball', 0.3463474214076996), ('gateball', 0.3459596037864685), ('skittle', 0.3450402021408081), ('idbf', 0.34496015310287476), ('itsf', 0.3448476791381836), ('cuppers', 0.34475481510162354), ('paintballing', 0.3447377681732178), ('senayan', 0.34414857625961304), ('helliniko', 0.3441334664821625), ('rollerblading', 0.34367620944976807), ('sdar', 0.3432502746582031), ('tnsra', 0.34272080659866333), ('dandamudi', 0.3427111804485321), ('polo', 0.3424569070339203), ('footgolf', 0.3422098755836487), ('kabadi', 0.34219419956207275), ('qgsssa', 0.3419812321662903), ('chess', 0.34113600850105286), ('stoolball', 0.34084030985832214), ('bowls', 0.34079504013061523), ('kolven', 0.34075039625167847), ('qtf', 0.3404190242290497), ('jakabaring', 0.34037065505981445), ('dragonboat', 0.33918288350105286), ('kyorugi', 0.3390512466430664), ('canchas', 0.33739131689071655), ('bheemili', 0.33726048469543457), ('jogging', 0.3369113802909851), ('ssireum', 0.3363635241985321), ('woodball', 0.3357526659965515), ('cuju', 0.3350004255771637), ('decamentathlon', 0.334879994392395), ('unicycling', 0.33461156487464905), ('extracurricular', 0.334513783454895), ('tournament', 0.3343808054924011), ('motorcross', 0.3341989517211914), ('rollerskating', 0.3340620994567871), ('ladies', 0.3340522348880768), ('xiangqi', 0.33399760723114014), ('superseries', 0.33386725187301636), ('racquet', 0.3335232734680176), ('chinlone', 0.33351561427116394), ('ndca', 0.3327702581882477), ('wintersports', 0.3326739966869354), ('quizzing', 0.33266502618789673), ('rosmalen', 0.33239084482192993), ('realplay', 0.33214277029037476), ('wovd', 0.3314521908760071), ('rinks', 0.33042365312576294), ('sukamta', 0.33024030923843384), ('oceania', 0.3300585150718689), ('ibsa', 0.3299490213394165), ('mallakhamb', 0.3297567665576935), ('stiga', 0.32846686244010925), ('velodromes', 0.3275640606880188), ('danda', 0.3272811770439148), ('teambath', 0.32673364877700806), ('quizzes', 0.3265770673751831), ('pastimes', 0.32657280564308167), ('sascoc', 0.3264700770378113), ('sandboarding', 0.3263150453567505), ('aquathlon', 0.32617175579071045)]
l2 = [('dancing', 0.7293938398361206), ('dances', 0.6974636316299438), ('dancers', 0.6168098449707031), ('music', 0.5861227512359619), ('danced', 0.5857449173927307), ('disco', 0.5755483508110046), ('singing', 0.5678908228874207), ('choreography', 0.5617600083351135), ('breakdance', 0.55570387840271), ('breakdancing', 0.5509804487228394), ('rhumba', 0.5495680570602417), ('ballet', 0.5437581539154053), ('salsa', 0.5409477353096008), ('voguing', 0.5331746935844421), ('musical', 0.5319218635559082), ('tango', 0.5315476059913635), ('jitterbug', 0.5296791195869446), ('bhangra', 0.5280084609985352), ('krump', 0.5237826108932495), ('zapateado', 0.5195732116699219), ('cabaret', 0.5111221075057983), ('cueca', 0.5081112384796143), ('kecak', 0.5063177347183228), ('jazz', 0.5062183141708374), ('dancer', 0.5047745108604431), ('lambada', 0.5042762756347656), ('rumba', 0.5040974617004395), ('milonga', 0.5024347305297852), ('karaoke', 0.5014785528182983), ('butoh', 0.5013641119003296), ('quadrille', 0.49984171986579895), ('sing', 0.4989587664604187), ('velfarre', 0.49888965487480164), ('lavani', 0.4979197084903717), ('flamenco', 0.4967549741268158), ('striptease', 0.49574756622314453), ('pop', 0.49517548084259033), ('choreographies', 0.49311941862106323), ('choreographed', 0.4930289685726166), ('chhau', 0.48805323243141174), ('quickstep', 0.4872487783432007), ('azonto', 0.4871146082878113), ('acrobatics', 0.4870259761810303), ('burlesque', 0.4846310019493103), ('tandav', 0.48261523246765137), ('aerobics', 0.48070457577705383), ('doublebugg', 0.4805515706539154), ('yosakoi', 0.4802190363407135), ('choreographing', 0.47958898544311523), ('denishawn', 0.4779616892337799), ('candombe', 0.47738978266716003), ('agbadza', 0.47678646445274353), ('tandava', 0.47650957107543945), ('giddha', 0.47568127512931824), ('folklorico', 0.4739644527435303), ('ghoomar', 0.4736197590827942), ('chorus', 0.4736101031303406), ('sattriya', 0.47289377450942993), ('xibelani', 0.4720681607723236), ('ländler', 0.47098809480667114), ('kamsale', 0.47083747386932373), ('sket', 0.4697437286376953), ('bikutsi', 0.4693523347377777), ('“dance', 0.4672355353832245), ('balletic', 0.46712952852249146), ('ballroom', 0.46497344970703125), ('veeragase', 0.46389830112457275), ('danza', 0.4637860357761383), ('sirtaki', 0.46232324838638306), ('reggae', 0.4621005654335022), ('merengue', 0.4617142081260681), ('marinera', 0.46077075600624084), ('bolero', 0.460528701543808), ('bedhaya', 0.4602239727973938), ('cumbia', 0.4597851037979126), ('scatting', 0.45780014991760254), ('stomp', 0.4576489329338074), ('improv', 0.4571237564086914), ('mimes', 0.45648759603500366), ('choreographs', 0.45582735538482666), ('folk', 0.4558061957359314), ('majorettes', 0.45571112632751465), ('samba', 0.4557054042816162), ('chinelos', 0.454847514629364), ('improvisation', 0.4546830356121063), ('rap', 0.4543365240097046), ('kroncong', 0.4534270465373993), ('pangalay', 0.4532994031906128), ('pilobolus', 0.45315709710121155), ('twerk', 0.45306506752967834), ('jaipongan', 0.45298048853874207), ('europop', 0.4526462256908417), ('tarantella', 0.45252639055252075), ('odissi', 0.4523927569389343), ('bugaku', 0.4517984986305237), ('ceilidh', 0.45170673727989197), ('choreographic', 0.45110058784484863), ('choreograph', 0.45107966661453247), ('gombey', 0.4510485827922821), ('yakshagana', 0.4509691298007965), ('cakewalk', 0.4508815109729767), ('krumping', 0.4507080316543579), ('trance', 0.4501875042915344), ('serimpi', 0.4501381516456604), ('unsquare', 0.4489145874977112), ('concert', 0.44808509945869446), ('downtempo', 0.44796010851860046), ('mohiniyattam', 0.4478057026863098), ('song', 0.44767269492149353), ('clap', 0.44762519001960754), ('fatele', 0.44671839475631714), ('dancehall', 0.4466445744037628), ('masquerade', 0.4465915560722351), ('kathak', 0.44655823707580566), ('vengaboys', 0.44622090458869934), ('performing', 0.44572630524635315), ('drumming', 0.44466471672058105), ('candoco', 0.44462692737579346), ('hoedown', 0.4443613886833191), ('danse', 0.4439435601234436), ('danzón', 0.44377148151397705), ('electroclash', 0.4427725076675415), ('calypso', 0.44272011518478394), ('jumpstyle', 0.4418230354785919), ('mujra', 0.44153398275375366), ('technopop', 0.44149601459503174), ('sardana', 0.4414176344871521), ('bharatanatyam', 0.4411270022392273), ('jwé', 0.44093358516693115), ('legong', 0.44041329622268677), ('performers', 0.43997761607170105), ('choreographer', 0.43985670804977417), ('mariachi', 0.4398197531700134), ('waltz', 0.43898075819015503), ('twerking', 0.43861129879951477), ('koodiyattam', 0.43760812282562256), ('sanjuanito', 0.43749988079071045), ('eurodance', 0.43689239025115967), ('clowning', 0.43674755096435547), ('tinikling', 0.43674373626708984), ('hiphop', 0.4366811513900757), ('hula', 0.4359002113342285), ('dollu', 0.43571895360946655), ('juggling', 0.43540793657302856), ('worldbeat', 0.43527060747146606), ('dance”', 0.43497323989868164), ('improvisational', 0.43472403287887573), ('tsifteteli', 0.4346471428871155), ('fandangos', 0.4345545172691345), ('festejo', 0.434395432472229), ('funky', 0.43406549096107483), ('reog', 0.43398553133010864), ('rave', 0.43325692415237427), ('beatboxing', 0.4331611394882202), ('singalong', 0.4328249990940094), ('miming', 0.431310772895813), ('bélé', 0.43109574913978577), ('discothèque', 0.43080875277519226), ('bachata', 0.4305045008659363), ('ballerinas', 0.4304622709751129), ('rhythm', 0.4300968647003174), ('bellydance', 0.4294828176498413), ('frevo', 0.42890724539756775), ('kuduro', 0.42885398864746094), ('gagaku', 0.4285739064216614), ('puppetry', 0.4280586838722229), ('zumba', 0.42804986238479614), ('acapella', 0.42804092168807983), ('csárdás', 0.42794257402420044), ('zonaradiko', 0.4278334379196167), ('polka', 0.4277292490005493), ('natyam', 0.4273149073123932), ('heelwork', 0.42706459760665894), ('acrobatic', 0.4267767667770386), ('qawwali', 0.42644041776657104), ('choreology', 0.42574775218963623), ('piano', 0.4255959987640381), ('musicals', 0.425437331199646), ('mambo', 0.42543214559555054), ('conga', 0.42523401975631714), ('coppélia', 0.4251957833766937), ('choreographers', 0.4251691699028015), ('techno', 0.42502233386039734), ('dancefloors', 0.42477136850357056), ('kuchipudi', 0.4245041608810425), ('lmfao', 0.42442047595977783), ('electropop', 0.4240041971206665), ('kuthiyottam', 0.42397287487983704), ('serenades', 0.4233527183532715), ('chachachá', 0.4233502745628357), ('zouk', 0.42331284284591675), ('waacking', 0.42310822010040283), ('extravaganzas', 0.4230729937553406), ('gymnastic', 0.42285478115081787), ('contortionists', 0.4228367805480957), ('pasodoble', 0.42212262749671936), ('lasya', 0.4221140146255493), ('bharatnatyam', 0.4220907688140869), ('folkdancing', 0.421735942363739), ('crazes', 0.42118197679519653)]
l3 = [('shooters', 0.5839959383010864), ('fencer', 0.47483381628990173), ('swimmer', 0.4717562198638916), ('athlete', 0.4700905978679657), ('sniper', 0.46852821111679077), ('pistol', 0.4566332697868347), ('marksman', 0.45616453886032104), ('cyclist', 0.44912588596343994), ('skier', 0.44888412952423096), ('racer', 0.4388149082660675), ('rower', 0.4348030686378479), ('sprinter', 0.4328063130378723), ('snowboarder', 0.43219679594039917), ('biathlete', 0.4310360550880432), ('diver', 0.42585206031799316), ('skeet', 0.41765159368515015), ('wibarm', 0.41650390625), ('wrestler', 0.41438812017440796), ('weightlifter', 0.41145652532577515), ('judoka', 0.41135793924331665), ('bobsledder', 0.411095529794693), ('platformer', 0.4106416702270508), ('player', 0.4034614562988281), ('shooting', 0.40326938033103943), ('jumper', 0.4025408923625946), ('motorcyclist', 0.40171319246292114), ('rpg', 0.40154457092285156), ('hurdler', 0.3999409079551697), ('climber', 0.3996546268463135), ('assassin', 0.39668703079223633), ('fitasc', 0.3947528600692749), ('gunman', 0.39313316345214844), ('ambidextrous', 0.39267534017562866), ('thrower', 0.3885214328765869), ('rifleman', 0.38785719871520996), ('gymnast', 0.3866426348686218), ('boxer', 0.38448983430862427), ('driver', 0.38374224305152893), ('decathlete', 0.38254472613334656), ('skater', 0.3793855607509613), ('airgun', 0.37726297974586487), ('sharpshooter', 0.37571027874946594), ('psikyo', 0.3752862811088562), ('handgun', 0.3747468888759613), ('racewalker', 0.3696509003639221), ('archer', 0.3685884475708008), ('luger', 0.3674139380455017), ('canoeist', 0.36726438999176025), ('putter', 0.3670186400413513), ('shotgun', 0.36670324206352234), ('benchrest', 0.3666534423828125), ('hitman', 0.3654554784297943), ('platforming', 0.364943265914917), ('afanasijs', 0.36305034160614014), ('windsurfer', 0.3628705143928528), ('policeman', 0.3612276017665863), ('zapper', 0.36041274666786194), ('powerlifter', 0.3601263165473938), ('crossbow', 0.3599129915237427), ('varmint', 0.3590443432331085), ('golfer', 0.3575657606124878), ('rider', 0.3567202389240265), ('multidirectional', 0.35450273752212524), ('shot', 0.35419192910194397), ('attacker', 0.3531474471092224), ('revolver', 0.35242176055908203), ('danmaku', 0.3516288101673126), ('pentathlete', 0.3507067859172821), ('kassoumi', 0.34991687536239624), ('soldier', 0.34933698177337646), ('firearm', 0.3487339913845062), ('copter', 0.3485904633998871), ('stealth', 0.3479793071746826), ('game', 0.347600519657135), ('roguelike', 0.34756195545196533), ('jetpack', 0.34747087955474854), ('semiautomatic', 0.3472636342048645), ('karateka', 0.34646672010421753), ('triathlete', 0.3452744483947754), ('paintball', 0.3451027274131775), ('grappler', 0.34507840871810913), ('leaper', 0.3438417613506317), ('sidescrolling', 0.34358662366867065), ('carbine', 0.3406783640384674), ('tracker', 0.33916404843330383), ('cricketer', 0.33819153904914856), ('bullseye', 0.33751362562179565), ('daneka', 0.3368118703365326), ('bazooka', 0.33604374527931213), ('gameplay', 0.3354418873786926), ('skydiver', 0.33524420857429504), ('rifle', 0.3350697457790375), ('stinger', 0.3349030613899231), ('cartridge', 0.33366847038269043), ('skateboarder', 0.3335672914981842), ('bullet', 0.3326196074485779), ('scrolling', 0.3326058089733124), ('projectile', 0.3321573734283447), ('brawler', 0.33150219917297363), ('šekarić', 0.3297663927078247), ('sailor', 0.32895660400390625), ('slingshot', 0.32891154289245605), ('khuru', 0.3288556933403015), ('javelin', 0.3275739252567291), ('stuntman', 0.32701319456100464), ('ipsc', 0.3263959288597107), ('muzzleloading', 0.32639384269714355), ('fireteam', 0.3262825310230255), ('séwé', 0.3249647617340088), ('decocked', 0.32440316677093506), ('plinking', 0.32435038685798645), ('bolt', 0.3242696523666382), ('rpgs', 0.32314103841781616), ('bushmaster', 0.3231280446052551), ('stalker', 0.32270434498786926), ('smallbore', 0.3224446773529053), ('speargun', 0.3223345875740051), ('gun', 0.32193896174430847), ('archery', 0.32186567783355713), ('autoloading', 0.32137739658355713), ('kickboxer', 0.321205198764801), ('bodybuilder', 0.32003700733184814), ('uspsa', 0.31957125663757324), ('adventure', 0.3193095922470093), ('minigun', 0.3189091682434082), ('foregrip', 0.31850022077560425), ('trooper', 0.3184337615966797), ('decocker', 0.31841152906417847), ('toaplan', 0.31841084361076355), ('kayaker', 0.3182595372200012), ('kenjū', 0.3179856538772583), ('launcher', 0.3177267014980316), ('sidescroller', 0.3176882863044739), ('aviator', 0.31748542189598083), ('avenger', 0.31719011068344116), ('barreled', 0.31672239303588867), ('centerfire', 0.31588220596313477), ('canoer', 0.31550133228302), ('lightgun', 0.31510013341903687), ('qix', 0.31496691703796387), ('miculek', 0.31432658433914185), ('murderer', 0.314164400100708), ('silencer', 0.3141371011734009), ('kuzmins', 0.31409814953804016), ('trap', 0.3138418197631836), ('curler', 0.3136349320411682), ('swordsman', 0.3135276436805725), ('airsoft', 0.3134233355522156), ('balkline', 0.31304967403411865), ('sportsman', 0.3129391670227051), ('gambler', 0.31278035044670105), ('striker', 0.31269556283950806), ('vepr', 0.312685489654541), ('programmer', 0.3126240670681), ('paracanoeist', 0.31242847442626953), ('cheytac', 0.3122407793998718), ('hollowpoint', 0.31220197677612305), ('hovertank', 0.31208571791648865), ('holster', 0.31183069944381714), ('infiltrator', 0.3117569386959076), ('fighter', 0.311653196811676), ('karasevdas', 0.3113710284233093), ('metroidvania', 0.3113568425178528), ('weapon', 0.31105056405067444), ('bullpup', 0.3109741806983948), ('uncocked', 0.31079214811325073), ('snowboarding', 0.31069812178611755), ('sportsperson', 0.31025344133377075), ('menacer', 0.31017714738845825), ('contestant', 0.30994951725006104), ('grenade', 0.3097352683544159), ('issachenko', 0.3097071647644043), ('coxswain', 0.30967727303504944), ('theofilakis', 0.30956941843032837), ('pepperbox', 0.30952271819114685), ('yelavich', 0.30936163663864136), ('quarterstaff', 0.3093363046646118), ('puzzle', 0.30925601720809937), ('wipiiti', 0.30919569730758667), ('flamethrower', 0.3087173104286194), ('ballhandler', 0.3085099756717682), ('blade', 0.3083975315093994), ('mauser', 0.30831944942474365), ('isometric', 0.3080984055995941), ('holstered', 0.3079381287097931), ('mech', 0.3071333169937134), ('bipod', 0.30691078305244446), ('bowhunter', 0.30646005272865295), ('arcade', 0.3059096336364746), ('qbu', 0.30568912625312805), ('accutrigger', 0.30568134784698486), ('chokehold', 0.30549854040145874), ('gumshoe', 0.3052000105381012), ('gündegmaa', 0.30469071865081787), ('saboteur', 0.3045848608016968), ('olympian', 0.3044329881668091), ('melee', 0.3043678402900696), ('ristar', 0.30415230989456177), ('safecracker', 0.30400168895721436), ('pugilist', 0.3036114573478699)]
l4 = [('psychotherapeutic', 0.7584818005561829), ('psychoanalysis', 0.7531128525733948), ('psychodynamic', 0.7231154441833496), ('psychoanalytic', 0.7220649719238281), ('hypnotherapy', 0.6887781023979187), ('psychiatry', 0.6729432344436646), ('therapy', 0.6623799800872803), ('psychology', 0.655338704586029), ('psychotherapies', 0.6486225724220276), ('gestalt', 0.6419842839241028), ('psychopathology', 0.6355389356613159), ('transpersonal', 0.6304964423179626), ('psychosynthesis', 0.6144720911979675), ('psychopharmacology', 0.6140667796134949), ('psychologists', 0.6048161387443542), ('psychoanalytical', 0.6048059463500977), ('adlerian', 0.6007553339004517), ('counseling', 0.5991020202636719), ('neuropsychology', 0.5987240672111511), ('jungian', 0.5983935594558716), ('hypnosis', 0.5976368188858032), ('rebt', 0.5952243804931641), ('reichian', 0.5912772417068481), ('ericksonian', 0.589699387550354), ('psychotherapists', 0.589052677154541), ('counselling', 0.5848536491394043), ('mindfulness', 0.5805827379226685), ('countertransference', 0.5805290341377258), ('psychological', 0.574944794178009), ('psychotherapist', 0.5748035907745361), ('pedagogy', 0.5733145475387573), ('neuroscience', 0.5729901790618896), ('psychodrama', 0.5709974765777588), ('bobath', 0.5657105445861816), ('therapeutic', 0.5646595358848572), ('psychosocial', 0.5611957907676697), ('clinical', 0.5608171820640564), ('integrative', 0.5601161122322083), ('neurology', 0.5552607774734497), ('psychiatric', 0.5544133186340332), ('therapists', 0.5534657835960388), ('sexology', 0.5524768829345703), ('neuropsychiatry', 0.5516846179962158), ('phenomenology', 0.5505357980728149), ('therapies', 0.547878623008728), ('reparative', 0.547724723815918), ('abreaction', 0.5440893769264221), ('biofeedback', 0.5434392094612122), ('psychoanalyst', 0.5407552719116211), ('psychodynamics', 0.540048360824585), ('freudian', 0.5378590226173401), ('therapist', 0.5347398519515991), ('rogerian', 0.5324465036392212), ('hypnotism', 0.5321430563926697), ('psychoanalysts', 0.5319421887397766), ('neuropathology', 0.5283111333847046), ('meditation', 0.5272200107574463), ('behavioral', 0.527167797088623), ('pharmacotherapy', 0.5235609412193298), ('neurofeedback', 0.5230658054351807), ('sociological', 0.5224730968475342), ('psychosurgery', 0.5224440097808838), ('chiropractic', 0.5218794345855713), ('psychopathological', 0.5209540724754333), ('humanistic', 0.5196229219436646), ('psychobiology', 0.5195361375808716), ('clinicians', 0.5192168951034546), ('psychophysiology', 0.5184686183929443), ('cbt', 0.5178181529045105), ('homeopathy', 0.5146256685256958), ('behaviorism', 0.5137636661529541), ('graphology', 0.5133278369903564), ('cognitive', 0.5111690163612366), ('logotherapy', 0.5108636021614075), ('neuroscientific', 0.5108217000961304), ('ect', 0.5106832981109619), ('psychosomatic', 0.5080084800720215), ('psychometrics', 0.5069552063941956), ('anthroposophy', 0.5065832734107971), ('schizophrenia', 0.5047452449798584), ('acupuncture', 0.5044410228729248), ('manualized', 0.5034641027450562), ('psychiatrists', 0.5030590891838074), ('neuropsychologist', 0.5017755627632141), ('neurophysiology', 0.5016745924949646), ('nondirective', 0.4992116093635559), ('psychoeducational', 0.4988590478897095), ('ethnomethodology', 0.49797964096069336), ('freud', 0.4976577162742615), ('pediatric', 0.49684417247772217), ('electroconvulsive', 0.4962139129638672), ('cognition', 0.49607354402542114), ('cbasp', 0.4956386685371399), ('geriatrics', 0.4950268268585205), ('parapsychology', 0.494067519903183), ('attunement', 0.4930275082588196), ('phenomenological', 0.49261319637298584), ('neurobiology', 0.4923725128173828), ('lacanian', 0.49207478761672974), ('neurosciences', 0.4881742596626282), ('holistic', 0.4874715805053711), ('therapy”', 0.4862724542617798), ('pediatrics', 0.48597508668899536), ('mentalization', 0.48475000262260437), ('dermatology', 0.48267078399658203), ('autosuggestion', 0.4824374318122864), ('neuroimaging', 0.4819754362106323), ('neurosurgical', 0.48186594247817993), ('experiential', 0.481670618057251), ('osteopathy', 0.48165586590766907), ('semiotics', 0.4814765155315399), ('casriel', 0.4813791513442993), ('parapsychological', 0.48097988963127136), ('bioethics', 0.4807701110839844), ('multimodality', 0.48046666383743286), ('breathwork', 0.48046326637268066), ('neuropsychiatric', 0.4802975058555603), ('hypnotherapists', 0.4800548851490021), ('neurobiological', 0.47871628403663635), ('gerontology', 0.47871071100234985), ('reparenting', 0.4780961871147156), ('bioenergetic', 0.4777916669845581), ('midwifery', 0.477084755897522), ('practitioners', 0.4763583540916443), ('feldenkrais', 0.4753999412059784), ('psychopharmacological', 0.4750228524208069), ('epistemology', 0.47498780488967896), ('mental', 0.47371184825897217), ('sociometry', 0.4729738235473633), ('neuroendocrinology', 0.4728143811225891), ('hermeneutics', 0.4722016751766205), ('cbtraining', 0.4718005061149597), ('megavitamin', 0.4709091782569885), ('philosophy', 0.4707229733467102), ('psychoses', 0.470491886138916), ('naturopathy', 0.470223069190979), ('palliative', 0.46879637241363525), ('spirituality', 0.4680071473121643), ('praxis', 0.46777284145355225), ('sociology', 0.46772319078445435), ('gynecology', 0.46719497442245483), ('psycholinguistics', 0.4670713245868683), ('rheumatology', 0.46678903698921204), ('interventions', 0.4658541679382324), ('physiotherapy', 0.4657058119773865), ('mesmerism', 0.4654017984867096), ('psychologist', 0.4652690887451172), ('adolescents', 0.4652653634548187), ('neuroplasticity', 0.4650631546974182), ('psychedelics', 0.464730441570282), ('lifetrack', 0.464429646730423), ('teaching', 0.464317262172699), ('victimology', 0.4642741084098816), ('psychoeducation', 0.46410128474235535), ('neurologists', 0.46379607915878296), ('psychophysiological', 0.46378493309020996), ('interdisciplinary', 0.4631273150444031), ('psychobiological', 0.4629366993904114), ('orthodontics', 0.46250441670417786), ('endocrinologists', 0.46225500106811523), ('freud’s', 0.46203890442848206), ('neuroscientists', 0.4614059627056122), ('metacognition', 0.46131759881973267), ('analytic', 0.4610751271247864), ('teacch', 0.46079760789871216), ('criminology', 0.4607003927230835), ('mbsr', 0.4605596959590912), ('anthropology', 0.46043282747268677), ('neurosurgery', 0.4601445198059082), ('methodological', 0.460064172744751), ('metapsychology', 0.46001219749450684), ('neurochemistry', 0.45960506796836853), ('yoga', 0.45930731296539307), ('janov', 0.4588853716850281), ('transference', 0.4585500955581665), ('narth', 0.4581450819969177), ('cardiologists', 0.45768973231315613), ('psychoneuroimmunology', 0.45765772461891174), ('pharmacology', 0.45736268162727356), ('epidemiology', 0.4565092623233795), ('sexological', 0.45619893074035645), ('geriatric', 0.4556468725204468), ('ophthalmology', 0.45563238859176636), ('lacan', 0.4553479850292206), ('menninger', 0.4553210735321045), ('analytical', 0.455161452293396), ('sexologists', 0.45473629236221313), ('psychoanalytically', 0.4546632766723633), ('orthoptic', 0.4540848433971405), ('neuroanatomy', 0.4540160894393921), ('lothane', 0.45391446352005005), ('wundt', 0.4537564516067505), ('anesthesiology', 0.4531702995300293), ('parenting', 0.4528482258319855), ('endocrinology', 0.45278722047805786), ('study', 0.4525500237941742), ('electrotherapy', 0.45214393734931946), ('vygotsky', 0.45187801122665405), ('argumentation', 0.45175740122795105), ('transcultural', 0.4516323506832123)]

# %%
d5 = dict(l1)
d6 = dict(l2)
d7 = dict(l3)
d8 = dict(l4)

# %%
print("novice")
th1 = 0.4
th2 =0.1
o1, o2 = get_count(d5,th1,th2)
o3, o4 = get_count(d6,th1,th2)
o5, o6 = get_count(d7,th1,th2)
o7, o8 = get_count(d8,th1,th2)
print('badminton: {} {}'.format(o1,o2))
print('dance:{} {}'.format(o3,o4))
print('shooter:{} {}'.format(o5,o6))
print('psychotherapy:{} {}'.format(o7,o8))
# Out:
# novice
# badminton: 62 138
# dance:200 0
# shooter:27 173
# psychotherapy:200 0
